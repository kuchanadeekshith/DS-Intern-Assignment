# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sklearn

# %%
df=pd.read_csv("data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16857 entries, 0 to 16856
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   timestamp                     16857 non-null  object
#  1   equipment_energy_consumption  16013 non-null  object
#  2   lighting_energy               16048 non-null  object
#  3   zone1_temperature             15990 non-null  object
#  4   zone1_humidity                16056 non-null  object
#  5   zone2_temperature             16004 non-null  object
#  6   zone2_humidity                15990 non-null  float64
#  7   zone3_temperature             16055 non-null  float64
#  8   zone3_humidity                15979 non-null  float64
#  9   zone4_temperature             16041 non-null  float64
#  10  zone4_humidity                16076 non-null  float64
#  11  zone5_temperature             16019 non-null  float64
# ...

# %%
df['time']=df['timestamp'].astype('datetime64[ns]')

# %%
df = df.drop("timestamp",axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16857 entries, 0 to 16856
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   equipment_energy_consumption  16013 non-null  object
#  1   lighting_energy               16048 non-null  object
#  2   zone1_temperature             15990 non-null  object
#  3   zone1_humidity                16056 non-null  object
#  4   zone2_temperature             16004 non-null  object
#  5   zone2_humidity                15990 non-null  float64
#  6   zone3_temperature             16055 non-null  float64
#  7   zone3_humidity                15979 non-null  float64
#  8   zone4_temperature             16041 non-null  float64
#  9   zone4_humidity                16076 non-null  float64
#  10  zone5_temperature             16019 non-null  float64
#  11  zone5_humidity                16056 non-null  float64
# ...

# %%
df['equipment_energy_consumption']=pd.to_numeric(df['equipment_energy_consumption'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16857 entries, 0 to 16856
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   equipment_energy_consumption  15945 non-null  float64
#  1   lighting_energy               16048 non-null  object
#  2   zone1_temperature             15990 non-null  object
#  3   zone1_humidity                16056 non-null  object
#  4   zone2_temperature             16004 non-null  object
#  5   zone2_humidity                15990 non-null  float64
#  6   zone3_temperature             16055 non-null  float64
#  7   zone3_humidity                15979 non-null  float64
#  8   zone4_temperature             16041 non-null  float64
#  9   zone4_humidity                16076 non-null  float64
#  10  zone5_temperature             16019 non-null  float64
#  11  zone5_humidity                16056 non-null  float64
# ...

# %%
df['lighting_energy']=pd.to_numeric(df['lighting_energy'],errors='coerce')

# %%
df['zone1_humidity']=pd.to_numeric(df['zone1_humidity'],errors='coerce')

# %%
df['zone1_temperature']=pd.to_numeric(df['zone1_temperature'],errors='coerce')

# %%
df['zone2_temperature']=pd.to_numeric(df['zone2_temperature'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16857 entries, 0 to 16856
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   equipment_energy_consumption  15945 non-null  float64
#  1   lighting_energy               15993 non-null  float64
#  2   zone1_temperature             15908 non-null  float64
#  3   zone1_humidity                15969 non-null  float64
#  4   zone2_temperature             15934 non-null  float64
#  5   zone2_humidity                15990 non-null  float64
#  6   zone3_temperature             16055 non-null  float64
#  7   zone3_humidity                15979 non-null  float64
#  8   zone4_temperature             16041 non-null  float64
#  9   zone4_humidity                16076 non-null  float64
#  10  zone5_temperature             16019 non-null  float64
#  11  zone5_humidity                16056 non-null  float64
# ...

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(x=df['time'],y=df['equipment_energy_consumption'])
# Out:
# <Axes: xlabel='time', ylabel='equipment_energy_consumption'>

# %%
df['equipment_energy_consumption'].isnull().sum()
# Out:
# np.int64(912)

# %%
import missingno as msno

# Visualize missing data
msno.matrix(df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['equipment_energy_consumption'])
# Out:
# <Axes: xlabel='equipment_energy_consumption'>

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x=df['equipment_energy_consumption'])
# Out:
# <Axes: xlabel='equipment_energy_consumption', ylabel='Count'>

# %%
df['equipment_energy_consumption'].unique()
# Out:
# array([   60.        ,    50.        ,            nan,    70.        ,
#          230.        ,   580.        ,   430.        ,   250.        ,
#          100.        ,    90.        ,    80.        ,   140.        ,
#          120.        ,   190.        ,   110.        ,   400.        ,
#          390.        ,   240.        ,    40.        ,    30.        ,
#          310.        ,   380.        ,   370.        ,    20.        ,
#         -110.        ,   260.        ,   500.        ,   450.        ,
#          220.        ,   170.        ,   290.        ,   130.        ,
#          200.        ,   210.        ,   -50.        ,   -20.        ,
#         -944.566411  ,   350.        ,   300.        ,  -400.        ,
#          340.        ,   150.        ,   330.        ,   420.        ,
#          520.        ,   360.        ,  -270.        ,   -30.        ,
#          180.        ,   550.        ,   690.        ,   620.        ,
# ...

# %%
df['equipment_energy_consumption']=df['equipment_energy_consumption'].ffill()

# %%
df['equipment_energy_consumption'].isnull().sum()
# Out:
# np.int64(0)

# %%
negative=df[df['equipment_energy_consumption']<0]

# %%
negative
# Out:
#        equipment_energy_consumption  lighting_energy  zone1_temperature  \
# 91                      -110.000000             30.0          19.790000
# 164                      -50.000000              0.0          20.000000
# 189                      -20.000000              0.0          19.390000
# 207                     -944.566411              0.0          19.100000
# 239                     -400.000000             20.0          18.856667
# ...                             ...              ...                ...
# 16704                    -50.000000              0.0          22.890000
# 16729                   -610.000000              0.0          22.700000
# 16741                    -70.000000              0.0          23.033333
# 16783                   -200.000000              0.0          24.790000
# 16794                   -944.566411              NaN                NaN
#
#        zone1_humidity  zone2_temperature  zone2_humidity  zone3_temperature  \
# ...

# %%
df=df[df['equipment_energy_consumption']>0]

# %%
df=df.ffill()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16526 entries, 0 to 16856
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   equipment_energy_consumption  16526 non-null  float64
#  1   lighting_energy               16526 non-null  float64
#  2   zone1_temperature             16526 non-null  float64
#  3   zone1_humidity                16526 non-null  float64
#  4   zone2_temperature             16526 non-null  float64
#  5   zone2_humidity                16526 non-null  float64
#  6   zone3_temperature             16526 non-null  float64
#  7   zone3_humidity                16525 non-null  float64
#  8   zone4_temperature             16526 non-null  float64
#  9   zone4_humidity                16526 non-null  float64
#  10  zone5_temperature             16526 non-null  float64
#  11  zone5_humidity                16526 non-null  float64
# ...

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(x=df['time'],y=df['equipment_energy_consumption'])
# Out:
# <Axes: xlabel='time', ylabel='equipment_energy_consumption'>

# %%
'''
numeric_features = df.select_dtypes(include='number').columns


sns.pairplot(df[numeric_features])'''
# Out:
# "\nnumeric_features = df.select_dtypes(include='number').columns\n\n\nsns.pairplot(df[numeric_features])"

# %%
temp=df[df['zone1_humidity']<0]

# %%
df.zone1_humidity.value_counts()
# Out:
# zone1_humidity
# 76.292756    169
# 3.348060     169
# 39.090000    136
# 37.200000    131
# 36.900000    126
#             ...
# 30.856667      1
# 30.663333      1
# 31.493333      1
# 31.323333      1
# 31.530000      1
# Name: count, Length: 2150, dtype: int64

# %%
df['zone1_humidity'] = df['zone1_humidity'].apply(lambda x: -x if x < 0 else x)

df['zone2_humidity'] = df['zone2_humidity'].apply(lambda x: -x if x < 0 else x)

df['zone3_humidity'] = df['zone3_humidity'].apply(lambda x: -x if x < 0 else x)

df['zone4_humidity'] = df['zone4_humidity'].apply(lambda x: -x if x < 0 else x)

df['zone5_humidity'] = df['zone5_humidity'].apply(lambda x: -x if x < 0 else x)

df['zone6_humidity'] = df['zone6_humidity'].apply(lambda x: -x if x < 0 else x)

df['zone7_humidity'] = df['zone7_humidity'].apply(lambda x: -x if x < 0 else x)

df['zone8_humidity'] = df['zone8_humidity'].apply(lambda x: -x if x < 0 else x)

df['zone9_humidity'] = df['zone9_humidity'].apply(lambda x: -x if x < 0 else x)


df['visibility_index'] = df['visibility_index'].apply(lambda x: -x if x < 0 else x)
df['outdoor_humidity'] = df['outdoor_humidity'].apply(lambda x: -x if x < 0 else x)
df['wind_speed'] = df['wind_speed'].apply(lambda x: -x if x < 0 else x)

# %%
df.describe()
# Out:
#        equipment_energy_consumption  lighting_energy  zone1_temperature  \
# count                  16526.000000     16526.000000       16526.000000
# mean                     108.851958         3.940405          21.247420
# min                       10.000000       -86.002966           8.726818
# 25%                       50.000000         0.000000          20.500000
# 50%                       60.000000         0.000000          21.323333
# 75%                      100.000000         0.000000          22.100000
# max                     1139.985693        86.002966          33.746609
# std                      149.218899        14.563664           2.143414
#
#        zone1_humidity  zone2_temperature  zone2_humidity  zone3_temperature  \
# count    16526.000000       16526.000000    16526.000000       16526.000000
# mean        39.811545          19.793675       40.219173          21.676627
# min          3.348060           2.988199        3.193842           6.543921
# ...

# %%
df['day']=df['time'].dt.day
df['month']=df['time'].dt.month
df['year']=df['time'].dt.year
df['quarter']=df['time'].dt.quarter
df['week']=df['time'].dt.isocalendar().week
df['dayofweek']=df['time'].dt.dayofweek

# %%
df['hour']=df['time'].dt.hour
df['minute']=df['time'].dt.minute

# %%
df['week']=df['week']%4+1

# %%
df
# Out:
#        equipment_energy_consumption  lighting_energy  zone1_temperature  \
# 0                         60.000000       -77.787786          33.746609
# 1                         60.000000        30.000000          19.890000
# 2                         50.000000        30.000000          19.890000
# 3                         50.000000        40.000000          33.746609
# 4                         60.000000        40.000000          19.890000
# ...                             ...              ...                ...
# 16852                   1139.985693        20.000000          22.100000
# 16853                     50.000000        86.002966          21.290000
# 16854                     50.000000         0.000000          21.390000
# 16855                     80.000000         0.000000          22.500000
# 16856                     30.000000         0.000000          20.066667
#
#        zone1_humidity  zone2_temperature  zone2_humidity  zone3_temperature  \
# ...

# %%
df.week.value_counts()
# Out:
# week
# 3    4605
# 4    3987
# 1    3972
# 2    3962
# Name: count, dtype: Int64

# %%
df=df.drop('time',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16526 entries, 0 to 16856
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   equipment_energy_consumption  16526 non-null  float64
#  1   lighting_energy               16526 non-null  float64
#  2   zone1_temperature             16526 non-null  float64
#  3   zone1_humidity                16526 non-null  float64
#  4   zone2_temperature             16526 non-null  float64
#  5   zone2_humidity                16526 non-null  float64
#  6   zone3_temperature             16526 non-null  float64
#  7   zone3_humidity                16525 non-null  float64
#  8   zone4_temperature             16526 non-null  float64
#  9   zone4_humidity                16526 non-null  float64
#  10  zone5_temperature             16526 non-null  float64
#  11  zone5_humidity                16526 non-null  float64
# ...

# %%
df['zone3_humidity']=df['zone3_humidity'].bfill()
df['zone6_temperature']=df['zone6_temperature'].bfill()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16526 entries, 0 to 16856
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   equipment_energy_consumption  16526 non-null  float64
#  1   lighting_energy               16526 non-null  float64
#  2   zone1_temperature             16526 non-null  float64
#  3   zone1_humidity                16526 non-null  float64
#  4   zone2_temperature             16526 non-null  float64
#  5   zone2_humidity                16526 non-null  float64
#  6   zone3_temperature             16526 non-null  float64
#  7   zone3_humidity                16526 non-null  float64
#  8   zone4_temperature             16526 non-null  float64
#  9   zone4_humidity                16526 non-null  float64
#  10  zone5_temperature             16526 non-null  float64
#  11  zone5_humidity                16526 non-null  float64
# ...
